# %%
import pandas as pd

# %%
import seaborn as sb
low_memory=False
# %matplotlib inline

# %%
df = pd.read_csv('gastos-deputados-39482a86c4d442ac974a31b12b629ec3.csv')

# %%
df
# Out:
#      numano  nummes                 datemissao   txnomeparlamentar sgpartido  \
# 0      2019       2  2019-02-07 00:00:00+00:00      PAULO TEIXEIRA        PT
# 1      2019       2  2019-02-06 00:00:00+00:00    CARLOS ZARATTINI        PT
# 2      2019       2  2019-02-06 00:00:00+00:00      PAULO TEIXEIRA        PT
# 3      2019       2  2019-02-06 00:00:00+00:00      PAULO TEIXEIRA        PT
# 4      2019       2  2019-02-06 00:00:00+00:00      PAULO TEIXEIRA        PT
# 5      2019       2  2019-02-05 00:00:00+00:00    CARLOS ZARATTINI        PT
# 6      2019       2  2019-02-05 00:00:00+00:00    CARLOS ZARATTINI        PT
# 7      2019       2  2019-02-05 00:00:00+00:00    CARLOS ZARATTINI        PT
# 8      2019       2  2019-02-05 00:00:00+00:00      PAULO TEIXEIRA        PT
# 9      2019       2  2019-02-05 00:00:00+00:00      PAULO TEIXEIRA        PT
# 10     2019       2  2019-02-05 00:00:00+00:00         NILTO TATTO        PT
# ...

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of      numano  nummes                 datemissao   txnomeparlamentar sgpartido  \
# 0      2019       2  2019-02-07 00:00:00+00:00      PAULO TEIXEIRA        PT
# 1      2019       2  2019-02-06 00:00:00+00:00    CARLOS ZARATTINI        PT
# 2      2019       2  2019-02-06 00:00:00+00:00      PAULO TEIXEIRA        PT
# 3      2019       2  2019-02-06 00:00:00+00:00      PAULO TEIXEIRA        PT
# 4      2019       2  2019-02-06 00:00:00+00:00      PAULO TEIXEIRA        PT
# 5      2019       2  2019-02-05 00:00:00+00:00    CARLOS ZARATTINI        PT
# 6      2019       2  2019-02-05 00:00:00+00:00    CARLOS ZARATTINI        PT
# 7      2019       2  2019-02-05 00:00:00+00:00    CARLOS ZARATTINI        PT
# 8      2019       2  2019-02-05 00:00:00+00:00      PAULO TEIXEIRA        PT
# 9      2019       2  2019-02-05 00:00:00+00:00      PAULO TEIXEIRA        PT
# 10     2019       2  2019-02-05 00:00:00+00:00         NILTO TATTO        PT
# ...

# %%
# %matplotlib notebook 
df[['txnomeparlamentar','vlrliquido']].hist(bins=30,alpha=0.5,color='Black')
# Out:
# <img src="data:image/png;base64,..." width="432">
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00996890>]],
#       dtype=object)
